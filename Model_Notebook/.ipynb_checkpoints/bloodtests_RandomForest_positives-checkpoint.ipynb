# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('../Resources/diagnosis-of-covid-19-and-its-clinical-spectrum.csv')
dataset.tail()
# Out:
#            patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 5639  ae66feb9e4dc3a0                     3               positive
# 5640  517c2834024f3ea                    17               negative
# 5641  5c57d6037fe266d                     4               negative
# 5642  c20c44766f28291                    10               negative
# 5643  2697fdccbfeb7f7                    19               positive
#
#      patient_addmited_to_regular_ward_1_yes_0_no  \
# 5639                                           f
# 5640                                           f
# 5641                                           f
# 5642                                           f
# 5643                                           f
#
#      patient_addmited_to_semi_intensive_unit_1_yes_0_no  \
# 5639                                                  f
# 5640                                                  f
# 5641                                                  f
# 5642                                                  f
# 5643                                                  f
#
#      patient_addmited_to_intensive_care_unit_1_yes_0_no  hematocrit  \
# 5639                                                  f         NaN
# 5640                                                  f         NaN
# 5641                                                  f         NaN
# 5642                                                  f         NaN
# 5643                                                  f    0.694287
#
#       hemoglobin  platelets  mean_platelet_volume  ...  \
# 5639         NaN        NaN                   NaN  ...
# 5640         NaN        NaN                   NaN  ...
# 5641         NaN        NaN                   NaN  ...
# 5642         NaN        NaN                   NaN  ...
# 5643    0.541564  -0.906829             -0.325903  ...
#
#       hb_saturation_arterial_blood_gases  pco2_arterial_blood_gas_analysis  \
# 5639                                 NaN                               NaN
# 5640                                 NaN                               NaN
# 5641                                 NaN                               NaN
# 5642                                 NaN                               NaN
# 5643                                 NaN                               NaN
#
#       base_excess_arterial_blood_gas_analysis  ph_arterial_blood_gas_analysis  \
# 5639                                      NaN                             NaN
# 5640                                      NaN                             NaN
# 5641                                      NaN                             NaN
# 5642                                      NaN                             NaN
# 5643                                      NaN                             NaN
#
#       total_co2_arterial_blood_gas_analysis  hco3_arterial_blood_gas_analysis  \
# 5639                                    NaN                               NaN
# 5640                                    NaN                               NaN
# 5641                                    NaN                               NaN
# 5642                                    NaN                               NaN
# 5643                                    NaN                               NaN
#
#       po2_arterial_blood_gas_analysis  arteiral_fio2  phosphor  \
# 5639                              NaN            NaN       NaN
# 5640                              NaN            NaN       NaN
# 5641                              NaN            NaN       NaN
# 5642                              NaN            NaN       NaN
# 5643                              NaN            NaN       NaN
#
#       cto2_arterial_blood_gas_analysis
# 5639                               NaN
# 5640                               NaN
# 5641                               NaN
# 5642                               NaN
# 5643                               NaN
#
# [5 rows x 111 columns]

# %%
dataset_new = dataset[['patient_id','patient_age_quantile','sars_cov_2_exam_result','leukocytes', 'platelets', 'monocytes', 'hematocrit', 'eosinophils', 'red_blood_cells', 'hemoglobin', 'lymphocytes', 'mean_platelet_volume']].copy()
dataset_new.head()
# Out:
#         patient_id  patient_age_quantile sars_cov_2_exam_result  leukocytes  \
# 0  44477f75e8169d2                    13               negative         NaN
# 1  126e9dd13932f68                    17               negative    -0.09461
# 2  a46b4402a0e5696                     8               negative         NaN
# 3  f7d619a94f97c45                     5               negative         NaN
# 4  d9e41465789c2b5                    15               negative         NaN
#
#    platelets  monocytes  hematocrit  eosinophils  red_blood_cells  hemoglobin  \
# 0        NaN        NaN         NaN          NaN              NaN         NaN
# 1  -0.517413   0.357547    0.236515     1.482158         0.102004    -0.02234
# 2        NaN        NaN         NaN          NaN              NaN         NaN
# 3        NaN        NaN         NaN          NaN              NaN         NaN
# 4        NaN        NaN         NaN          NaN              NaN         NaN
#
#    lymphocytes  mean_platelet_volume
# 0          NaN                   NaN
# 1     0.318366              0.010677
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN

# %%
print(len(dataset_new.index))
# Out:
# 5644

# %%
dataset_new_filtered = dataset_new[dataset_new['sars_cov_2_exam_result'] == 'positive']
dataset_new_filtered.head(20)
# Out:
#            patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 67    78511c183ae18bc                     7               positive
# 284   d7834ed75f2da44                    16               positive
# 513   b16b49f7bd3e692                    10               positive
# 568   4382f5ea05e60c4                     2               positive
# 676   d3729cd2658ca64                    15               positive
# 884   ab9745da9d139b9                    15               positive
# 1011  a0435dd40e745fd                     7               positive
# 1108  9d7c293a6773d6a                    14               positive
# 1113  ff5ec3abd7d6088                     5               positive
# 1129  7b1d6bf5993aa9b                     9               positive
# 1156  1e7e33688edc5a9                    11               positive
# 1162  2a5db9bbb45109f                    14               positive
# 1168  3fc734fd9bafbd6                    18               positive
# 1193  057e8ce3c6f2f31                    14               positive
# 1194  f0ee30f04652697                    11               positive
# 1196  8fac8033edbd319                    13               positive
# 1201  219ad2543c93936                    14               positive
# 1205  ff34f2c79fc6cf0                     7               positive
# 1232  fbec53bbe8c576a                     6               positive
# 1268  66d288d2a12ca60                    14               positive
#
#       leukocytes  platelets  monocytes  hematocrit  eosinophils  \
# 67           NaN        NaN        NaN         NaN          NaN
# 284          NaN        NaN        NaN         NaN          NaN
# 513          NaN        NaN        NaN         NaN          NaN
# 568    -0.420197  -0.341548   1.933339    0.991838    -0.498393
# 676          NaN        NaN        NaN         NaN          NaN
# 884    -0.820919  -0.718402  -0.456613   -0.495919    -0.666950
# 1011         NaN        NaN        NaN         NaN          NaN
# 1108   -0.968407  -0.027502   1.513128   -0.312811     0.175837
# 1113         NaN        NaN        NaN         NaN          NaN
# 1129         NaN        NaN        NaN         NaN          NaN
# 1156         NaN        NaN        NaN         NaN          NaN
# 1162   -0.573250  -0.215930   2.537393   -0.518807    -0.709090
# 1168         NaN        NaN        NaN         NaN          NaN
# 1193         NaN        NaN        NaN         NaN          NaN
# 1194         NaN        NaN        NaN         NaN          NaN
# 1196         NaN        NaN        NaN         NaN          NaN
# 1201         NaN        NaN        NaN         NaN          NaN
# 1205         NaN        NaN        NaN         NaN          NaN
# 1232         NaN        NaN        NaN         NaN          NaN
# 1268         NaN        NaN        NaN         NaN          NaN
#
#       red_blood_cells  hemoglobin  lymphocytes  mean_platelet_volume
# 67                NaN         NaN          NaN                   NaN
# 284               NaN         NaN          NaN                   NaN
# 513               NaN         NaN          NaN                   NaN
# 568          1.653476    0.792188    -0.048383              1.469188
# 676               NaN         NaN          NaN                   NaN
# 884         -0.567950   -0.398276    -0.935404             -0.438097
# 1011              NaN         NaN          NaN                   NaN
# 1108        -0.656101   -0.648900    -0.099557             -0.101517
# 1113              NaN         NaN          NaN                   NaN
# 1129              NaN         NaN          NaN                   NaN
# 1156              NaN         NaN          NaN                   NaN
# 1162        -0.515058   -0.272964    -0.457777              0.459449
# 1168              NaN         NaN          NaN                   NaN
# 1193              NaN         NaN          NaN                   NaN
# 1194              NaN         NaN          NaN                   NaN
# 1196              NaN         NaN          NaN                   NaN
# 1201              NaN         NaN          NaN                   NaN
# 1205              NaN         NaN          NaN                   NaN
# 1232              NaN         NaN          NaN                   NaN
# 1268              NaN         NaN          NaN                   NaN
